# %%
## Underfitting & Overfitting :

# %%
# Underfitting : Not working on training or testing

## How to handle?
-- Add more data
-- Add complexity to model
-- reduce noise in data
-- train on more epochs

# %%
## Overfitting : perform well on training but fails on testing data

## How to handle?
-- Train on more diverse data
-- Regularization :
        -- L1 : The absolute value of the magnitude of the weight added to cost function.
        -- L2 : Sum of squares of the magnitude of the weight added to cost function.

        -- Dropout : Randomly drop neurons during training
        -- Early stopping : stop training when validation loss is not improving

# %%
train
test

# %%
## Vanishing & Exploding gradients :

# %%
# Vanishing Gradients :
-- To update weights we need gradients
-- gradients are calculated using chain rule
-- If gradient have smaller value

-- If gradient value become too small, resulat will be even more smaller
-- If gradient value become too small, there will be no update weight

##Handling vanishing gradients :
-- Avoide using sigmoide & tanh in hedden layer
-- prefer relu or its varients in hidden layer
-- use batch normalization or layer normalization
-- use residual connection : add input of layer in output of that layer

# %%
0.7 * 0.2 * 0.1
# Out:
# 0.013999999999999999

# %%
W_new = W_old - L.R * dJ/dw

      9 - 0.013

# %%
9 - 0.013
# Out:
# 8.987

# %%
## Exploding gradients :
-- This occurs when gradient value is too large

## Handling Exploding gradients :
-- Gradient clipping : set threshold range
                       if graient value goes out of range
                       replace it with threshold value

# %%
0.5 - 1
